# %% [markdown]
# # 1. Imports and Setup
# Project modules and required functions are imported. The system path is updated so `src` modules can be accessed.

# %%
import sys
from pathlib import Path
project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.utils import *
from src.hmm import HMM
from src.analysis import *

# %% [markdown]
# # 2. Train HMM
# A Hidden Markov Model (HMM) is initialized. Start and transition probabilities are set and emission probabilities are estimated from human CDS data.
#
# Note: If you would like to use different data to train the model you can replace the file path assigned to the `filename` variable to the path to your file.

# %%
filename = "../data/GCF_000001405.40_GRCh38.p14_cds_from_genomic.fna.gz"
hmm = HMM()
hmm.initialize_parameters()
hmm.train_emission_probs_from_fasta(fasta_filename=filename, max_codons=None)

# %% [markdown]
# # 3. Gene Analysis
# Influenza A genes are analyzed and results for each gene is printed. The results include:
#
# + The average adaptation score for each gene.
# + Top K Viterbi paths.
# + Adaptation scores and Viterbi log scores for each path.

# %%
input_file = "../data/influenza_A_genes.txt"
gene_dict = load_fasta_dict(input_file)
results = analyze_genes(gene_dict, hmm, K=2)

for gene_id, data in results.items():
            print(f"Gene: {gene_id}")
            print(f"Average adaptation score: {data['avg_adaptation_score']}")

            for i, p in enumerate(data["paths"], start=1):
                print(f"Path {i}: {p['path']}")
                print(f"Adaptation score: {p['adaptation_score']}")
                print(f"Viterbi log-score: {p['viterbi_log_score']}")

            print()
# Out:
# Gene: lcl|LC660659.1_cds_BDC79445.1_1
# Average adaptation score: 0.724
# Path 1: ...
# Adaptation score: 0.7301587301587301
# Viterbi log-score: -2510.6873081763188
# Path 2: ...
# Adaptation score: 0.7178130511463845
# Viterbi log-score: -2510.724668516883
#
# Gene: lcl|LC660660.1_cds_BDC79446.1_1
# Average adaptation score: 0.824
# Path 1: ...
# Adaptation score: 0.8256513026052105
# Viterbi log-score: -2202.844686095867
# Path 2: ...
# Adaptation score: 0.8216432865731463
# Viterbi log-score: -2202.9036889891922
#
# Gene: lcl|LC660661.1_cds_BDC79447.1_1
# Average adaptation score: 0.701
# Path 1: ...
# Adaptation score: 0.7106382978723405
# Viterbi log-score: -2099.713706030665
# Path 2: ...
# Adaptation score: 0.6914893617021277
# Viterbi log-score: -2099.72130270112
#
# Gene: lcl|LC660662.1_cds_BDC79448.1_1
# Average adaptation score: 0.668
# Path 1: AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNNNNNNNNNNNNNNNNNNNNNAAAAAAAAAAAAAAAAAAAAAAANNNNNNNNNN
# Adaptation score: 0.6224489795918368
# Viterbi log-score: -433.2462133310712
# Path 2: AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNNNNNNNNNNNNNNNNNNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAN
# Adaptation score: 0.7142857142857143
# Viterbi log-score: -433.3412462688864
#
# Gene: lcl|LC660662.1_cds_BDC79449.1_2
# Average adaptation score: 0.848
# Path 1: AAAAAAAANNNNNNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNNNNNNNNNAAAAAAAAAAAAAAAANNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNN
# Adaptation score: 0.8537549407114624
# Viterbi log-score: -1113.2933634084968
# Path 2: AAAAAAAANNNNNNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNNNNNNNNNAAAAAAAAAAAAAAAANNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNN
# Adaptation score: 0.841897233201581
# Viterbi log-score: -1113.29472399552
#
# Gene: lcl|LC660663.1_cds_BDC79450.1_1
# Average adaptation score: 0.832
# Path 1: AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNNNN
# Adaptation score: 0.8360655737704918
# Viterbi log-score: -538.8627573407504
# Path 2: AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNNNN
# Adaptation score: 0.8278688524590164
# Viterbi log-score: -538.9080909486447
#
# Gene: lcl|LC660663.1_cds_BDC79451.1_2
# Average adaptation score: 0.732
# Path 1: AAAAAAAAAANNNNNNNNNNNAAAAAAAAAAAAANNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNAAAAAAAAAAAAAAAAAAAANNNNNNNNNAAAAAAAAAAAANNNNNNNNNNNNNNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNNAAAAAAAAAAAAAAAAAAAAAAAAAN
# Adaptation score: 0.740909090909091
# Viterbi log-score: -977.4112477500584
# Path 2: AAAAAAAAAANNNNNNNNNNNAAAAAAAAAAAAANNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNAAAAAAAAAAAAAAAAAAAANNNNNNNNNAAAAAAAANNNNNNNNNNNNNNNNNNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNNAAAAAAAAAAAAAAAAAAAAAAAAAN
# Adaptation score: 0.7227272727272728
# Viterbi log-score: -977.4260632373582
#
# Gene: lcl|LC660658.1_cds_BDC79444.1_1
# Average adaptation score: 0.873
# Path 1: ...
# Adaptation score: 0.8758716875871687
# Viterbi log-score: -3138.6765651991072
# Path 2: ...
# Adaptation score: 0.8702928870292888
# Viterbi log-score: -3138.6840158366617
#
# Gene: lcl|LC660657.1_cds_BDC79443.1_1
# Average adaptation score: 0.79
# Path 1: ...
# Adaptation score: 0.7915567282321899
# Viterbi log-score: -3345.5489864021188
# Path 2: ...
# Adaptation score: 0.787598944591029
# Viterbi log-score: -3345.5549755498146
#
# Gene: lcl|LC660656.1_cds_BDC79442.1_1
# Average adaptation score: 0.898
# Path 1: ...
# Adaptation score: 0.9026315789473685
# Viterbi log-score: -3349.79108014066
# Path 2: ...
# Adaptation score: 0.8934210526315789
# Viterbi log-score: -3349.7963277821727

# %% [markdown]
# # 4. Ranked Genes
# Genes are ranked based on average adaptation score and printed in decreasing order.

# %%
sorted_genes = sorted(results.items(), key=lambda item: item[1]["avg_adaptation_score"], reverse=True)


for rank, (gene_id, data) in enumerate(sorted_genes, start=1):
    print(f"Rank {rank}: {gene_id}")
    print(f"Average adaptation score: {data['avg_adaptation_score']}")
    print()
# Out:
# Rank 1: lcl|LC660656.1_cds_BDC79442.1_1
# Average adaptation score: 0.898
#
# Rank 2: lcl|LC660658.1_cds_BDC79444.1_1
# Average adaptation score: 0.873
#
# Rank 3: lcl|LC660662.1_cds_BDC79449.1_2
# Average adaptation score: 0.848
#
# Rank 4: lcl|LC660663.1_cds_BDC79450.1_1
# Average adaptation score: 0.832
#
# Rank 5: lcl|LC660660.1_cds_BDC79446.1_1
# Average adaptation score: 0.824
#
# Rank 6: lcl|LC660657.1_cds_BDC79443.1_1
# Average adaptation score: 0.79
#
# Rank 7: lcl|LC660663.1_cds_BDC79451.1_2
# Average adaptation score: 0.732
#
# Rank 8: lcl|LC660659.1_cds_BDC79445.1_1
# Average adaptation score: 0.724
#
# Rank 9: lcl|LC660661.1_cds_BDC79447.1_1
# Average adaptation score: 0.701
#
# Rank 10: lcl|LC660662.1_cds_BDC79448.1_1
# Average adaptation score: 0.668
